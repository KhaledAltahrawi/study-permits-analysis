# %%
# === Setup / Imports ===
import os, calendar
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import FuncFormatter
import plotly.graph_objects as go
from IPython.display import Image, display

# Ensure output folders exist
os.makedirs("images", exist_ok=True)
os.makedirs("reports", exist_ok=True)

# Month mapping used throughout
MONTH_MAP = {'Jan':1,'Feb':2,'Mar':3,'Apr':4,'May':5,'Jun':6,'Jul':7,'Aug':8,'Sep':9,'Oct':10,'Nov':11,'Dec':12}

# Notes for fresh environments:
# pip install pandas matplotlib plotly kaleido

# %%
# Define the path to the Excel file
file_path = "study_permits_by_country_2015_2025.xlsx"

try:
    # Read the Excel file with specific parameters:
    # skiprows=2: Skip the first 2 rows. These rows contain introductory information
    #            or headers that are not part of the main data structure.
    # skipfooter=7: Skip the last 7 rows (footer). These rows contain
    #             summary statistics, notes, or other information not needed for the analysis.
    # header=[0, 1, 2]: Set the header as the rows at index 0, 1, and 2 (after skipping the initial rows).
    #                  These three rows together form the MultiIndex for the column names,
    #                  representing Year, Quarter, and Month/Total.
    df = pd.read_excel(file_path, skiprows=2, skipfooter=7, header=[0, 1, 2])

    # Function to flatten the MultiIndex columns into a single string
    def flatten_multiindex(col):
        if isinstance(col, tuple):
            # Join the parts of the tuple with ' - ' if they are not 'Unnamed'.
            # 'Unnamed' indicates merged cells in the original Excel sheet
            # that do not contain specific header information at that level.
            return ' - '.join(str(x) for x in col if 'Unnamed' not in str(x))
        return col

    # Apply the flatten_multiindex function to the columns to create simpler names
    df.columns = df.columns.map(flatten_multiindex)

    # Rename the first column, which contains the country names.
    # The original MultiIndex for this column spanned three rows with 'Unnamed' levels.
    df.rename(columns={'Country of Citizenship - Unnamed: 0_level_1 - Unnamed: 0_level_2': 'Country of Citizenship'}, inplace=True)

    # Display the cleaned column names to verify the transformation
    print("Cleaned Column Names:")
    print(df.columns)

    # Display the first few rows of the cleaned DataFrame to inspect the data structure
    print("\nFirst few rows of Cleaned DataFrame:")
    print(df.head())

except FileNotFoundError:
    # Handle the error if the specified file path does not exist
    print(f"Error: File '{file_path}' not found. Please check the path.")
except Exception as e:
    # Handle other potential errors that might occur during file reading
    print(f"An error occurred while reading the file: {e}")
# Out:
# Cleaned Column Names:
# Index(['Country of Citizenship', '2015 - Q1 - Jan', '2015 - Q1 - Feb',
#        '2015 - Q1 - Mar', '2015 - Q1 - Q1 Total', '2015 - Q2 - Apr',
#        '2015 - Q2 - May', '2015 - Q2 - Jun', '2015 - Q2 - Q2 Total',
#        '2015 - Q3 - Jul',
#        ...
#        '2025 - Q2 - Jun', '2025 - Q2 - Q2 Total', '2025 - Q3 - Jul',
#        '2025 - Q3 - Aug', '2025 - Q3 - Sep', '2025 - Q3 - Q3 Total',
#        '2025 - Q4 - Oct', '2025 - Q4 - Nov', '2025 - Q4 - Q4 Total',
#        '2025 - 2025 Total'],
#       dtype='object', length=187)
#
# First few rows of Cleaned DataFrame:
#   Country of Citizenship 2015 - Q1 - Jan 2015 - Q1 - Feb 2015 - Q1 - Mar  \
# 0            Afghanistan              10              --              --
# 1                Albania              10               5              --
# 2                Algeria              60              40              55
# 3                Andorra              --               0               0
# ...

# %%
# Identify columns containing 'Total'
columns_to_drop = [col for col in df.columns if 'Total' in col]

# Drop the identified columns
df_cleaned = df.drop(columns=columns_to_drop, errors='ignore')

# Display the remaining column names
print("\nColumn names after removing 'Total' columns:")
print(df_cleaned.columns)

# Display the first few rows of the cleaned DataFrame
print("\nFirst few rows of DataFrame after removing 'Total' columns:")
print(df_cleaned.head())
# Out:
# Column names after removing 'Total' columns:
# Index(['Country of Citizenship', '2015 - Q1 - Jan', '2015 - Q1 - Feb',
#        '2015 - Q1 - Mar', '2015 - Q2 - Apr', '2015 - Q2 - May',
#        '2015 - Q2 - Jun', '2015 - Q3 - Jul', '2015 - Q3 - Aug',
#        '2015 - Q3 - Sep',
#        ...
#        '2025 - Q1 - Feb', '2025 - Q1 - Mar', '2025 - Q2 - Apr',
#        '2025 - Q2 - May', '2025 - Q2 - Jun', '2025 - Q3 - Jul',
#        '2025 - Q3 - Aug', '2025 - Q3 - Sep', '2025 - Q4 - Oct',
#        '2025 - Q4 - Nov'],
#       dtype='object', length=132)
#
# First few rows of DataFrame after removing 'Total' columns:
#   Country of Citizenship 2015 - Q1 - Jan 2015 - Q1 - Feb 2015 - Q1 - Mar  \
# 0            Afghanistan              10              --              --
# 1                Albania              10               5              --
# 2                Algeria              60              40              55
# 3                Andorra              --               0               0
# ...

# %%
# Melt the DataFrame to long format
df_long = pd.melt(df_cleaned,
                  id_vars=['Country of Citizenship'],
                  var_name='Period',
                  value_name='Number of Students')

# Display the first few rows of the long format DataFrame
print("\nFirst few rows of DataFrame in long format (df_long):")
print(df_long.head())

# Display the shape of the long format DataFrame
print("\nShape of the long format DataFrame (df_long):", df_long.shape)
# Out:
# First few rows of DataFrame in long format (df_long):
#   Country of Citizenship           Period Number of Students
# 0            Afghanistan  2015 - Q1 - Jan                 10
# 1                Albania  2015 - Q1 - Jan                 10
# 2                Algeria  2015 - Q1 - Jan                 60
# 3                Andorra  2015 - Q1 - Jan                 --
# 4                 Angola  2015 - Q1 - Jan                 15
#
# Shape of the long format DataFrame (df_long): (28820, 3)

# %%
# Function to extract Year, Quarter, and Month from the 'Period' column
def extract_period_info(period_str):
    parts = period_str.split(' - ')
    year = int(parts[0])
    quarter = parts[1]
    month = parts[2]
    return pd.Series([year, quarter, month])

# Apply the function to create new 'Year', 'Quarter', and 'Month' columns
df_long[['Year', 'Quarter', 'Month']] = df_long['Period'].apply(extract_period_info)

# Display the first few rows of df_long with the new columns
print("\nFirst few rows of df_long with 'Year', 'Quarter', 'Month' columns:")
print(df_long)

# Display the data types of the new columns
print("\nData types of 'Year', 'Quarter', 'Month' columns:")
print(df_long[['Year', 'Quarter', 'Month']].dtypes)
# Out:
# First few rows of df_long with 'Year', 'Quarter', 'Month' columns:
#                   Country of Citizenship           Period Number of Students  \
# 0                            Afghanistan  2015 - Q1 - Jan                 10
# 1                                Albania  2015 - Q1 - Jan                 10
# 2                                Algeria  2015 - Q1 - Jan                 60
# 3                                Andorra  2015 - Q1 - Jan                 --
# 4                                 Angola  2015 - Q1 - Jan                 15
# ...                                  ...              ...                ...
# 28815                     Western Sahara  2025 - Q4 - Nov                  0
# 28816                              Yemen  2025 - Q4 - Nov                 15
# 28817                             Zambia  2025 - Q4 - Nov                 20
# 28818                           Zimbabwe  2025 - Q4 - Nov                 85
# ...

# %%
# Replace '--' with 0 in 'Number of Students'
df_long['Number of Students'] = df_long['Number of Students'].replace('--', 0)

# Remove commas and convert to integer
df_long['Number of Students'] = df_long['Number of Students'].astype(str).str.replace(',', '', regex=False)
df_long['Number of Students'] = pd.to_numeric(df_long['Number of Students'], errors='coerce').astype(int)

# Display the data type and first few rows
print("\nData type of 'Number of Students' column after cleaning and conversion:")
print(df_long['Number of Students'].dtype)
print("\nFirst few rows of df_long:")
print(df_long.head())
# Out:
# Data type of 'Number of Students' column after cleaning and conversion:
# int64
#
# First few rows of df_long:
#   Country of Citizenship           Period  Number of Students  Year Quarter  \
# 0            Afghanistan  2015 - Q1 - Jan                  10  2015      Q1
# 1                Albania  2015 - Q1 - Jan                  10  2015      Q1
# 2                Algeria  2015 - Q1 - Jan                  60  2015      Q1
# 3                Andorra  2015 - Q1 - Jan                   0  2015      Q1
# 4                 Angola  2015 - Q1 - Jan                  15  2015      Q1
#
#   Month
# 0   Jan
# 1   Jan
# 2   Jan
# 3   Jan
# 4   Jan

# %%
# === Analysis Time Context (Single Source of Truth) ===

import calendar

# Ensure MonthNum exists (safe re-derivation, no mutation risk)
df_time = df_long.copy()
df_time["MonthNum"] = df_time["Month"].map(MONTH_MAP).astype(int)

# Core boundaries
first_year = int(df_time["Year"].min())
latest_year = int(df_time["Year"].max())

# Latest available month in the latest year
latest_month = int(
    df_time.loc[df_time["Year"] == latest_year, "MonthNum"].max()
)
latest_month_name = calendar.month_name[latest_month]

# Detect whether the latest year is partial
months_in_latest_year = (
    df_time.loc[df_time["Year"] == latest_year, "MonthNum"].nunique()
)
is_partial_year = months_in_latest_year < 12

# Human-readable labels
if is_partial_year:
    analysis_period_label = f"{first_year}–{latest_year} (YTD through {latest_month_name})"
    latest_year_label = f"{latest_year} YTD ({latest_month_name})"
else:
    analysis_period_label = f"{first_year}–{latest_year}"
    latest_year_label = f"{latest_year} (Full Year)"

full_years_range_label = f"{first_year}–{latest_year - 1}" if is_partial_year else f"{first_year}–{latest_year}"

# Debug / visibility
print("=== Analysis Time Context ===")
print(f"First year: {first_year}")
print(f"Latest year: {latest_year}")
print(f"Latest month: {latest_month_name}")
print(f"Partial latest year: {is_partial_year}")
print(f"Analysis period label: {analysis_period_label}")
# Out:
# === Analysis Time Context ===
# First year: 2015
# Latest year: 2025
# Latest month: November
# Partial latest year: True
# Analysis period label: 2015–2025 (YTD through November)

# %%
# === Yearly totals (dynamic labels, update-proof) ===

import plotly.graph_objects as go
from IPython.display import Image, display
import os

# Ensure output folders exist
os.makedirs("images", exist_ok=True)
os.makedirs("reports", exist_ok=True)

# --- Yearly totals
yearly_totals = (
    df_long.groupby("Year", as_index=False)["Number of Students"]
           .sum()
           .sort_values("Year")
)

years  = yearly_totals["Year"].tolist()
values = yearly_totals["Number of Students"].tolist()
grand_total = int(sum(values))

# --- Build figure
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=years,
    y=values,
    mode="lines+markers",
    name="Yearly total",
    hovertemplate="<b>%{x}</b><br>Total: %{y:,}<extra></extra>",
    line=dict(width=3),
    marker=dict(size=8),
))

# --- Smart label placement
labels, offsets, positions = [], [], []
for i, v in enumerate(values):
    slope = (values[i] - values[i-1]) if i > 0 else 0
    base = 0.02
    close_adj = (i > 0 and abs(values[i] - values[i-1]) / max(values[i], 1) < 0.02)
    if close_adj:
        base *= 1.7
    offsets.append(v * (1 + base) if slope >= 0 else v * (1 - base))
    positions.append("top center" if slope >= 0 else "bottom center")
    labels.append(f"{v:,}")

annotations = []
for x, y, y_off, txt, pos in zip(years, values, offsets, labels, positions):
    yanchor = "bottom" if y_off > y else "top"
    annotations.append(dict(
        x=x,
        y=y_off,
        xref="x",
        yref="y",
        text=txt,
        showarrow=False,
        xanchor="center",
        yanchor=yanchor,
        bgcolor="rgba(255,255,255,0.85)",
        bordercolor="rgba(0,0,0,0.2)",
        borderwidth=1,
        font=dict(size=12),
    ))

# --- Partial-year marker (automatic)
if is_partial_year:
    fig.add_vline(
        x=latest_year,
        line_dash="dash",
        annotation_text=f"{latest_year} (through {latest_month_name})",
        annotation_position="top right",
    )

# --- Grand total annotation
annotations.append(dict(
    xref="paper",
    yref="paper",
    x=0.02,
    y=0.97,
    text=f"<b>Total ({analysis_period_label}):</b> {grand_total:,}",
    showarrow=False,
    align="left",
    font=dict(size=13),
    bgcolor="rgba(255,255,255,0.85)",
    bordercolor="rgba(0,0,0,0.25)",
    borderwidth=1,
    borderpad=4,
))

fig.update_layout(
    title=f"Total Study Permits Issued in Canada ({analysis_period_label})",
    xaxis_title="Year",
    yaxis_title="Number of Students",
    yaxis=dict(tickformat="~,"),
    hovermode="x unified",
    template="plotly_white",
    margin=dict(l=65, r=60, t=80, b=50),
    annotations=annotations,
)

# --- Export
fig.write_html(
    "reports/yearly_permits_trend.html",
    include_plotlyjs="cdn",
    full_html=True,
)
fig.write_image("images/yearly_permits_trend.png", scale=2)

display(Image(filename="images/yearly_permits_trend.png"))
print(f"Interactive version saved to reports/yearly_permits_trend.html")
print(f"Grand total ({analysis_period_label}): {grand_total:,}")
# Out:
# Interactive version saved to reports/yearly_permits_trend.html
# Grand total (2015–2025 (YTD through November)): 4,507,515

# %%
# === Top 10 Countries by Study Permits (update-proof) ===

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import os

os.makedirs("images", exist_ok=True)

# Aggregate total permits by country
country_permits = (
    df_long.groupby("Country of Citizenship")["Number of Students"]
           .sum()
           .sort_values(ascending=False)
)

top_10_countries = country_permits.head(10)

plt.figure(figsize=(14, 8))
bars = top_10_countries.plot(kind="bar", color="skyblue")

plt.title(
    f"Top 10 Countries for Study Permits in Canada ({analysis_period_label})",
    fontsize=16
)
plt.xlabel("Country of Citizenship", fontsize=12)
plt.ylabel("Total Number of Study Permits", fontsize=12)
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.yticks(fontsize=10)
plt.gca().yaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, p: format(int(x), ","))
)

# Value labels
for i, value in enumerate(top_10_countries):
    plt.text(
        i,
        value + max(top_10_countries) * 0.01,
        f"{int(value):,}",
        ha="center",
        va="bottom",
        fontsize=10,
        fontweight="bold",
    )

plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.savefig("images/top_10_countries.png", dpi=300)
plt.show()

# %%
# === Top 5 Countries – Grouped Bars (update-proof YTD logic) ===

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import os

os.makedirs("images", exist_ok=True)

top_n = 5

# Top countries based on full available period
totals_by_country = (
    df_long.groupby("Country of Citizenship")["Number of Students"]
           .sum()
           .sort_values(ascending=False)
)

top_countries = totals_by_country.head(top_n).index.tolist()

# Prepare YTD-safe dataset
df_ytd = df_long.copy()
df_ytd["MonthNum"] = df_ytd["Month"].map(MONTH_MAP).astype(int)

if is_partial_year:
    df_ytd = df_ytd[
        (df_ytd["Year"] < latest_year) |
        ((df_ytd["Year"] == latest_year) & (df_ytd["MonthNum"] <= latest_month))
    ]

# Aggregate
ytd = (
    df_ytd[df_ytd["Country of Citizenship"].isin(top_countries)]
    .groupby(["Year", "Country of Citizenship"], as_index=False)["Number of Students"]
    .sum()
)

years = sorted(ytd["Year"].unique().tolist())
x = np.arange(len(years))
width = 0.8 / len(top_countries)

fig, ax = plt.subplots(figsize=(13, 6))
ax.yaxis.set_major_formatter(FuncFormatter(lambda v, p: f"{int(v):,}"))

for i, country in enumerate(top_countries):
    values = [
        int(
            ytd.loc[
                (ytd["Year"] == year) &
                (ytd["Country of Citizenship"] == country),
                "Number of Students"
            ].sum()
        )
        for year in years
    ]
    ax.bar(
        x + i * width - (len(top_countries) - 1) * width / 2,
        values,
        width,
        label=country,
    )

# Title & labels
title_suffix = (
    f"{latest_year} YTD ({latest_month_name})"
    if is_partial_year
    else f"{latest_year} (Full Year)"
)

ax.set_title(
    f"Top 5 Countries – Study Permits ({first_year}–{title_suffix})",
    fontsize=14,
)
ax.set_xlabel("Year")
ax.set_ylabel("Number of Students")
ax.set_xticks(x)
ax.set_xticklabels(years)
ax.grid(axis="y", alpha=0.25)
ax.legend(ncols=min(5, top_n), frameon=False, title="Country")

# Annotation
if is_partial_year:
    ax.text(
        0.99,
        0.98,
        f"Note: {latest_year} includes data through {latest_month_name} only.",
        transform=ax.transAxes,
        ha="right",
        va="top",
        fontsize=10,
        bbox=dict(boxstyle="round,pad=0.25", fc="white", ec="0.8", alpha=0.9),
    )

plt.tight_layout()
plt.savefig("images/top_5_countries_trends_grouped_bars.png", dpi=300)
plt.show()

# %%
# === Monthly Distribution of Study Permits (update-proof) ===

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import calendar
import os

os.makedirs("images", exist_ok=True)

df_m = df_long.copy()
df_m["MonthNum"] = df_m["Month"].map(MONTH_MAP).astype(int)

# Apply YTD logic only if latest year is partial
if is_partial_year:
    df_m = df_m[
        (df_m["Year"] < latest_year) |
        ((df_m["Year"] == latest_year) & (df_m["MonthNum"] <= latest_month))
    ]

monthly_total = (
    df_m.groupby("MonthNum", as_index=False)["Number of Students"]
        .sum()
        .sort_values("MonthNum")
)

monthly_total["MonthName"] = monthly_total["MonthNum"].apply(
    lambda m: calendar.month_abbr[m]
)

fig, ax = plt.subplots(figsize=(12, 5))
bars = ax.bar(
    monthly_total["MonthName"],
    monthly_total["Number of Students"]
)

ax.set_title(
    f"Monthly Distribution of Study Permits ({analysis_period_label})",
    fontsize=14
)
ax.set_xlabel("Month")
ax.set_ylabel("Number of Students")
ax.yaxis.set_major_formatter(FuncFormatter(lambda v, p: f"{int(v):,}"))
ax.grid(axis="y", alpha=0.25)

# Value labels
for bar in bars:
    height = int(bar.get_height())
    ax.annotate(
        f"{height:,}",
        xy=(bar.get_x() + bar.get_width() / 2, height),
        xytext=(0, 3),
        textcoords="offset points",
        ha="center",
        va="bottom",
        fontsize=9,
    )

# Partial-year note
if is_partial_year:
    ax.text(
        0.99,
        0.98,
        f"Note: {latest_year} includes data through {latest_month_name} only.",
        transform=ax.transAxes,
        ha="right",
        va="top",
        fontsize=9,
        bbox=dict(boxstyle="round,pad=0.25", fc="white", ec="0.8", alpha=0.9),
    )

plt.tight_layout()
plt.savefig("images/monthly_distribution.png", dpi=300)
plt.show()

# %%
# === Year-over-Year % Change (update-proof) ===

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter
import os

os.makedirs("images", exist_ok=True)

df_yoy = df_long.copy()
df_yoy["MonthNum"] = df_yoy["Month"].map(MONTH_MAP).astype(int)

# Use full years + YTD for latest year if partial
if is_partial_year:
    df_yoy = df_yoy[
        (df_yoy["Year"] < latest_year) |
        ((df_yoy["Year"] == latest_year) & (df_yoy["MonthNum"] <= latest_month))
    ]

yearly_totals = (
    df_yoy.groupby("Year", as_index=False)["Number of Students"]
          .sum()
          .sort_values("Year")
)

yearly_totals["YoY_%"] = yearly_totals["Number of Students"].pct_change() * 100

years = yearly_totals["Year"].tolist()
yoy_vals = yearly_totals["YoY_%"].tolist()

fig, ax = plt.subplots(figsize=(12, 5))
bars = ax.bar(
    years,
    [0 if np.isnan(v) else v for v in yoy_vals]
)

ax.set_title(
    f"Year-over-Year % Change in Study Permits ({analysis_period_label})",
    fontsize=14
)
ax.set_xlabel("Year")
ax.set_ylabel("YoY Change (%)")
ax.axhline(0, color="black", linewidth=0.8)
ax.grid(axis="y", alpha=0.25)
ax.set_xticks(years)
ax.yaxis.set_major_formatter(FuncFormatter(lambda v, p: f"{v:.0f}%"))

# Labels
for bar, val in zip(bars, yoy_vals):
    if np.isnan(val):
        continue
    ax.annotate(
        f"{val:+.1f}%",
        xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()),
        xytext=(0, 3 if val >= 0 else -12),
        textcoords="offset points",
        ha="center",
        va="bottom" if val >= 0 else "top",
        fontsize=10,
        bbox=dict(boxstyle="round,pad=0.2", fc="white", ec="0.8", alpha=0.9),
    )

# Partial-year note
if is_partial_year:
    ax.text(
        0.99,
        0.98,
        f"Note: {latest_year} includes data through {latest_month_name} only.",
        transform=ax.transAxes,
        ha="right",
        va="top",
        fontsize=9,
        bbox=dict(boxstyle="round,pad=0.25", fc="white", ec="0.8", alpha=0.9),
    )

plt.tight_layout()
plt.savefig("images/ytd_yoy_change.png", dpi=300)
plt.show()
